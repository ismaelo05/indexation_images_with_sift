# %%
# Importation des librairies devant nous aider pour le projet
import glob
import cv2
import numpy as np
import os
# %matplotlib inline
from matplotlib import pyplot as plt
import natsort
import random
from collections import OrderedDict
import pickle
# !pip install lshashpy3
# !python -c "import lshashpy3 as lshash; print(lshash.__version__);"
from lshashpy3 import LSHash
from google.colab.patches import cv2_imshow
import shutil
from numpy.ma import fix_invalid
from tqdm import tqdm
import json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lshashpy3
#   Downloading lshashpy3-0.0.8.tar.gz (9.0 kB)
# Building wheels for collected packages: lshashpy3
#   Building wheel for lshashpy3 (setup.py) ... done
#   Created wheel for lshashpy3: filename=lshashpy3-0.0.8-py3-none-any.whl size=8903 sha256=eecde18b6511064f2958c04bee5b95605b2a83b08a78099fdefa27ee7ab06d6c
#   Stored in directory: /root/.cache/pip/wheels/32/9b/ae/27f94ba2cd85b1cd5af645fa78f90b703c9e1fb9e2b55a04e0
# Successfully built lshashpy3
# Installing collected packages: lshashpy3
# Successfully installed lshashpy3-0.0.8
# 0.0.8

# %%
# Télécharge notre dataset à partir de du drive en utilisant le lien de téléchargement et le dataset est public
# !gdown --id 1Ui6MDCkTjRVgw2A2l4QB--JJRVfxsS6q
# dézipper le fichier
# !unzip tobacco_examples.zip
# Supprimer le fichier zippé
# !rm -r /content/tobacco_examples.zip
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1Ui6MDCkTjRVgw2A2l4QB--JJRVfxsS6q
# To: /content/tobacco_examples.zip
# 100% 173M/173M [00:01<00:00, 95.2MB/s]
# Archive:  tobacco_examples.zip
#    creating: tobacco_examples/
#   inflating: __MACOSX/._tobacco_examples
#   inflating: tobacco_examples/.DS_Store
#   inflating: __MACOSX/tobacco_examples/._.DS_Store
#    creating: tobacco_examples/images/
#    creating: tobacco_examples/videos/
#   inflating: tobacco_examples/images/0048.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0048.jpg
#   inflating: tobacco_examples/images/0049.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0049.jpg
#   inflating: tobacco_examples/images/0006.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0006.jpg
#   inflating: tobacco_examples/images/0007.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0007.jpg
#   inflating: tobacco_examples/images/0013.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0013.jpg
#   inflating: tobacco_examples/images/0039.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0039.jpg
#   inflating: tobacco_examples/images/0038.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0038.jpg
#   inflating: tobacco_examples/images/0010.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0010.jpg
#   inflating: tobacco_examples/images/0004.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0004.jpg
#   inflating: tobacco_examples/images/0028.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0028.jpg
#   inflating: tobacco_examples/images/0015.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0015.jpg
#   inflating: tobacco_examples/images/0001.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0001.jpg
#   inflating: tobacco_examples/images/0029.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0029.jpg
#   inflating: tobacco_examples/images/0017.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0017.jpg
#   inflating: tobacco_examples/images/0002.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0002.jpg
#   inflating: tobacco_examples/images/0016.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0016.jpg
#   inflating: tobacco_examples/images/0033.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0033.jpg
#   inflating: tobacco_examples/images/0027.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0027.jpg
#   inflating: tobacco_examples/images/0026.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0026.jpg
#   inflating: tobacco_examples/images/0032.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0032.jpg
#   inflating: tobacco_examples/images/0024.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0024.jpg
#   inflating: tobacco_examples/images/0030.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0030.jpg
#   inflating: tobacco_examples/images/0031.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0031.jpg
#   inflating: tobacco_examples/images/0025.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0025.jpg
#   inflating: tobacco_examples/images/0021.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0021.jpg
#   inflating: tobacco_examples/images/0035.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0035.jpg
#   inflating: tobacco_examples/images/0034.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0034.jpg
#   inflating: tobacco_examples/images/0020.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0020.jpg
#   inflating: tobacco_examples/images/0008.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0008.jpg
#   inflating: tobacco_examples/images/0036.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0036.jpg
#   inflating: tobacco_examples/images/0022.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0022.jpg
#   inflating: tobacco_examples/images/0023.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0023.jpg
#   inflating: tobacco_examples/images/0037.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0037.jpg
#   inflating: tobacco_examples/images/0044.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0044.jpg
#   inflating: tobacco_examples/images/0045.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0045.jpg
#   inflating: tobacco_examples/images/0047.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0047.jpg
#   inflating: tobacco_examples/images/0053.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0053.jpg
#   inflating: tobacco_examples/images/0052.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0052.jpg
#   inflating: tobacco_examples/images/0046.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0046.jpg
#   inflating: tobacco_examples/images/0042.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0042.jpg
#   inflating: tobacco_examples/images/0056.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0056.jpg
#   inflating: tobacco_examples/images/0057.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0057.jpg
#   inflating: tobacco_examples/images/0043.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0043.jpg
#   inflating: tobacco_examples/images/0055.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0055.jpg
#   inflating: tobacco_examples/images/0041.jpg
#   inflating: __MACOSX/tobacco_examples/images/._0041.jpg
#   inflating: tobacco_examples/videos/7-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._7-TR.mp4
#   inflating: tobacco_examples/videos/57-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._57-BL.mp4
#   inflating: tobacco_examples/videos/15-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._15-TL.mp4
#   inflating: tobacco_examples/videos/33-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._33-BR.mp4
#   inflating: tobacco_examples/videos/38-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._38-BL.mp4
#   inflating: tobacco_examples/videos/26-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._26-BL.mp4
#   inflating: tobacco_examples/videos/21-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._21-BR.mp4
#   inflating: tobacco_examples/videos/31-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._31-TL.mp4
#   inflating: tobacco_examples/videos/36-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._36-TR.mp4
#   inflating: tobacco_examples/videos/55-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._55-TR.mp4
#   inflating: tobacco_examples/videos/52-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._52-TL.mp4
#   inflating: tobacco_examples/videos/28-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._28-TR.mp4
#   inflating: tobacco_examples/videos/17-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._17-BR.mp4
#   inflating: tobacco_examples/videos/10-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._10-BL.mp4
#   inflating: tobacco_examples/videos/23-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._23-TL.mp4
#   inflating: tobacco_examples/videos/24-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._24-TR.mp4
#   inflating: tobacco_examples/videos/23-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._23-BR.mp4
#   inflating: tobacco_examples/videos/24-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._24-BL.mp4
#   inflating: tobacco_examples/videos/47-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._47-BL.mp4
#   inflating: tobacco_examples/videos/31-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._31-BR.mp4
#   inflating: tobacco_examples/videos/55-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._55-BL.mp4
#   inflating: tobacco_examples/videos/52-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._52-BR.mp4
#   inflating: tobacco_examples/videos/28-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._28-BL.mp4
#   inflating: tobacco_examples/videos/17-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._17-TL.mp4
#   inflating: tobacco_examples/videos/10-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._10-TR.mp4
#   inflating: tobacco_examples/videos/42-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._42-TL.mp4
#   inflating: tobacco_examples/videos/38-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._38-TR.mp4
#   inflating: tobacco_examples/videos/26-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._26-TR.mp4
#   inflating: tobacco_examples/videos/21-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._21-TL.mp4
#   inflating: tobacco_examples/videos/15-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._15-BR.mp4
#   inflating: tobacco_examples/videos/34-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._34-TR.mp4
#   inflating: tobacco_examples/videos/33-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._33-TL.mp4
#   inflating: tobacco_examples/videos/7-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._7-BL.mp4
#   inflating: tobacco_examples/videos/2-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._2-TL.mp4
#   inflating: tobacco_examples/videos/29-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._29-TL.mp4
#   inflating: tobacco_examples/videos/16-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._16-BL.mp4
#   inflating: tobacco_examples/videos/53-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._53-TR.mp4
#   inflating: tobacco_examples/videos/37-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._37-TL.mp4
#   inflating: tobacco_examples/videos/46-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._46-TL.mp4
#   inflating: tobacco_examples/videos/22-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._22-TR.mp4
#   inflating: tobacco_examples/videos/25-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._25-TL.mp4
#   inflating: tobacco_examples/videos/35-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._35-BR.mp4
#   inflating: tobacco_examples/videos/32-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._32-BL.mp4
#   inflating: tobacco_examples/videos/13-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._13-TL.mp4
#   inflating: tobacco_examples/videos/27-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._27-BR.mp4
#   inflating: tobacco_examples/videos/20-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._20-BL.mp4
#   inflating: tobacco_examples/videos/43-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._43-BL.mp4
#   inflating: tobacco_examples/videos/6-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._6-TL.mp4
#   inflating: tobacco_examples/videos/1-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._1-TR.mp4
#   inflating: tobacco_examples/videos/4-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._4-BR.mp4
#   inflating: tobacco_examples/videos/4-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._4-TL.mp4
#   inflating: tobacco_examples/videos/6-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._6-BR.mp4
#   inflating: tobacco_examples/videos/1-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._1-BL.mp4
#   inflating: tobacco_examples/videos/27-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._27-TL.mp4
#   inflating: tobacco_examples/videos/39-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._39-TL.mp4
#   inflating: tobacco_examples/videos/43-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._43-TR.mp4
#   inflating: tobacco_examples/videos/35-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._35-TL.mp4
#   inflating: tobacco_examples/videos/48-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._48-TL.mp4
#   inflating: tobacco_examples/videos/13-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._13-BR.mp4
#   inflating: tobacco_examples/videos/56-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._56-TL.mp4
#   inflating: tobacco_examples/videos/46-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._46-BR.mp4
#   inflating: tobacco_examples/videos/41-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._41-BL.mp4
#   inflating: tobacco_examples/videos/22-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._22-BL.mp4
#   inflating: tobacco_examples/videos/16-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._16-TR.mp4
#   inflating: tobacco_examples/videos/53-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._53-BL.mp4
#   inflating: tobacco_examples/videos/30-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._30-BL.mp4
#   inflating: tobacco_examples/videos/16-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._16-BR.mp4
#   inflating: tobacco_examples/videos/53-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._53-TL.mp4
#   inflating: tobacco_examples/videos/30-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._30-TL.mp4
#   inflating: tobacco_examples/videos/37-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._37-TR.mp4
#   inflating: tobacco_examples/videos/46-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._46-TR.mp4
#   inflating: tobacco_examples/videos/41-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._41-TL.mp4
#   inflating: tobacco_examples/videos/22-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._22-TL.mp4
#   inflating: tobacco_examples/videos/25-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._25-TR.mp4
#   inflating: tobacco_examples/videos/35-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._35-BL.mp4
#   inflating: tobacco_examples/videos/32-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._32-BR.mp4
#   inflating: tobacco_examples/videos/48-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._48-BL.mp4
#   inflating: tobacco_examples/videos/13-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._13-TR.mp4
#   inflating: tobacco_examples/videos/56-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._56-BL.mp4
#   inflating: tobacco_examples/videos/27-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._27-BL.mp4
#   inflating: tobacco_examples/videos/20-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._20-BR.mp4
#   inflating: tobacco_examples/videos/39-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._39-BL.mp4
#   inflating: tobacco_examples/videos/43-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._43-BR.mp4
#   inflating: tobacco_examples/videos/6-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._6-TR.mp4
#   inflating: tobacco_examples/videos/1-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._1-TL.mp4
#   inflating: tobacco_examples/videos/4-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._4-BL.mp4
#   inflating: tobacco_examples/videos/4-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._4-TR.mp4
#   inflating: tobacco_examples/videos/6-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._6-BL.mp4
#   inflating: tobacco_examples/videos/1-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._1-BR.mp4
#   inflating: tobacco_examples/videos/27-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._27-TR.mp4
#   inflating: tobacco_examples/videos/20-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._20-TL.mp4
#   inflating: tobacco_examples/videos/43-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._43-TL.mp4
#   inflating: tobacco_examples/videos/44-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._44-TR.mp4
#   inflating: tobacco_examples/videos/35-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._35-TR.mp4
#   inflating: tobacco_examples/videos/32-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._32-TL.mp4
#   inflating: tobacco_examples/videos/13-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._13-BL.mp4
#   inflating: tobacco_examples/videos/46-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._46-BL.mp4
#   inflating: tobacco_examples/videos/16-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._16-TL.mp4
#   inflating: tobacco_examples/videos/29-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._29-BL.mp4
#   inflating: tobacco_examples/videos/53-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._53-BR.mp4
#   inflating: tobacco_examples/videos/30-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._30-BR.mp4
#   inflating: tobacco_examples/videos/7-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._7-TL.mp4
#   inflating: tobacco_examples/videos/57-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._57-BR.mp4
#   inflating: tobacco_examples/videos/15-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._15-TR.mp4
#   inflating: tobacco_examples/videos/49-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._49-BR.mp4
#   inflating: tobacco_examples/videos/34-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._34-BR.mp4
#   inflating: tobacco_examples/videos/33-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._33-BL.mp4
#   inflating: tobacco_examples/videos/42-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._42-BL.mp4
#   inflating: tobacco_examples/videos/45-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._45-BR.mp4
#   inflating: tobacco_examples/videos/38-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._38-BR.mp4
#   inflating: tobacco_examples/videos/26-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._26-BR.mp4
#   inflating: tobacco_examples/videos/21-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._21-BL.mp4
#   inflating: tobacco_examples/videos/31-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._31-TR.mp4
#   inflating: tobacco_examples/videos/36-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._36-TL.mp4
#   inflating: tobacco_examples/videos/55-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._55-TL.mp4
#   inflating: tobacco_examples/videos/52-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._52-TR.mp4
#   inflating: tobacco_examples/videos/17-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._17-BL.mp4
#   inflating: tobacco_examples/videos/28-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._28-TL.mp4
#   inflating: tobacco_examples/videos/10-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._10-BR.mp4
#   inflating: tobacco_examples/videos/24-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._24-TL.mp4
#   inflating: tobacco_examples/videos/47-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._47-TL.mp4
#   inflating: tobacco_examples/videos/23-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._23-BL.mp4
#   inflating: tobacco_examples/videos/24-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._24-BR.mp4
#   inflating: tobacco_examples/videos/31-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._31-BL.mp4
#   inflating: tobacco_examples/videos/52-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._52-BL.mp4
#   inflating: tobacco_examples/videos/17-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._17-TR.mp4
#   inflating: tobacco_examples/videos/28-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._28-BR.mp4
#   inflating: tobacco_examples/videos/10-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._10-TL.mp4
#   inflating: tobacco_examples/videos/45-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._45-TL.mp4
#   inflating: tobacco_examples/videos/38-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._38-TL.mp4
#   inflating: tobacco_examples/videos/26-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._26-TL.mp4
#   inflating: tobacco_examples/videos/21-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._21-TR.mp4
#   inflating: tobacco_examples/videos/57-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._57-TL.mp4
#   inflating: tobacco_examples/videos/15-BL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._15-BL.mp4
#   inflating: tobacco_examples/videos/49-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._49-TL.mp4
#   inflating: tobacco_examples/videos/34-TL.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._34-TL.mp4
#   inflating: tobacco_examples/videos/7-BR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._7-BR.mp4
#   inflating: tobacco_examples/videos/2-TR.mp4
#   inflating: __MACOSX/tobacco_examples/videos/._2-TR.mp4

# %% [markdown]
# # Cette fonction permet de lire nos données images et nos frames, elle va retourner:
#
#
# 1.   classe_vrai qui représente le nom de chaque frame
# 2.   label qui représente le nom de chacun de nos images
# 1.   jpg_names représente nos données images donc nous allons utiliser pour le calcul de nos descripteurs SIFT
# 2.   mp4_names représente le nom contenant le chemein d'accès à nos différentes vidéos

# %%
#Fonction permettant de lire notre dataset, labels
def images_numpy_images_videos(chemin):
  jpg_names = []
  mp4_names = []
  label = []
  classe_vrai = []
  for dirname, _, filenames in os.walk(chemin):
    for filename in filenames:
      if os.path.join(dirname, filename)[-3:] != 'jpg':
        if filename != '.DS_Store':
          name3, name4 = filename.split('.')
          name5, name6 = name3.split('-')
          if len(name5) == 1:
            name6 = '000'+str(name5)
          else:
            name6 = '00'+str(name5)
          classe_vrai.append(name6)
          mp4_names.append(os.path.join(dirname, filename))
          # print(filename)

      else:
        # print(filename)
        name1, name2 = filename.split('.')
        label.append(name1)
        # print(nom_doc)cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
        image = cv2.imread(os.path.join(dirname, filename))
        # print(filename)

        jpg_names.append(image)
  return classe_vrai, label, np.array(jpg_names), mp4_names

classe_vrai, label, jpg_names, mp4_names = images_numpy_images_videos('/content/tobacco_examples')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %% [markdown]
# # Afficher quelques images aléatoires de notre dataset

# %%
plt.figure(figsize=(10, 10))
for k, i in np.ndenumerate(np.random.randint(jpg_names.shape[0], size=8)):
    ax = plt.subplot(4, 4, 2 * k[0] + 1)
    plt.imshow(jpg_names[i], cmap='gray')
    plt.title('image {}'.format(i))
    plt.axis("off")
    x = plt.subplot(4, 4, 2 * k[0] + 2)
    plt.imshow(jpg_names[i+1], cmap='gray')
    plt.title('image {}'.format(i))
    plt.axis("off")

# %% [markdown]
# # Calcul des descripteurs de nos différentes images devant ètre indexés
#
#
# 1.   Čalcul des points d'intérèts et descripteurs de chacun des images de notre jeu de données
# 2.   Sélection de quelques vecteurs en tenant compte du seuil pris en paramètre

# %%
def calcul_descripteur_sift(listImage, seuil):
  # Creation de l'objet sift
  sift = cv2.SIFT_create(seuil)
  # Liste contenant les descripteurs
  liste_descripteur = []
  liste_key_point = []
  listeClasse = []
  # Parcourir les images de notre jeu de données d'entrainement
  for i, im in enumerate(listImage):
    # print(im.shape)
    
    # break
    # dim = (512, 512)
    # resize image
    # im = cv2.resize(im, dim, interpolation = cv2.INTER_AREA)
    # cv2_imshow(im)
    img1 = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    # Détection des points d'intérèts et des descripteurs de points d'intérèts 
    keypoint, descripteur = sift.detectAndCompute(img1,None)
    liste_descripteur.append(descripteur)
    liste_key_point.append(keypoint)
  
  return np.array(liste_descripteur)

descripteur= calcul_descripteur_sift(jpg_names, seuil= 200)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Crée un dossier vide devant contenir les images provenant des frames de nos vidéos
# !mkdir dossier1

# %% [markdown]
# # Fonction permettant de créer une image par fichier vidéo

# %%
# Fonction de création de fichier image 
def generate_une_image_par_frame(mp4_names):
  for name in mp4_names:
    a = name.split('/')
    c, d = a[len(a)-1].split('.')
    cap= cv2.VideoCapture(name)
    i = 0
    while(cap.isOpened()):
      ret, frame = cap.read()
      if ret == True and i == 0:
        # Sauvegarde chaque image dans le fichier dossier1
        cv2.imwrite('/content/dossier1/'+c+'.jpg',frame)
      if ret == False:
        break
      i += 1
    cap.release()
    cv2.destroyAllWindows()

generate_une_image_par_frame(mp4_names)

# %% [markdown]
# # Fonction permettant de créer une liste d'images devant servir pour la requète ainsi que leur noms

# %%
# Fonction permettant de lire les images dans dossier1 
def read_image_test(chemin):
  image_names = []
  label_frame = []
  for dirname, _, filenames in os.walk(chemin):
    for filename in filenames:
      if os.path.join(dirname, filename)[-3:] == 'jpg':
          image = cv2.imread(os.path.join(dirname, filename))
          a, b = filename.split('.')
          # Met le nom du fichier sans extension dans une liste
          label_frame.append(a)
          # Sauve chaque image dans une liste
          image_names.append(image)
  # retourne les fichier devant servir pour la requète et leur nom
  return np.array(image_names), label_frame

image_test, fichier_name_test = read_image_test('/content/dossier1')

# %% [markdown]
# # Fonction permettant de créer la table de hachage de notre jeu de données

# %%
def table_hash(descripteurs, label):
  # Initialisation de l'objet LSH avec comme paramètre le nombre de bits 6 et la dimension
  # correspondant à la dimension de nos descrpiteurs
  lsh = LSHash(6, 128)
  i=0
  essai = {}
  for element in descripteurs:
    for vector in element:
      lsh.index(vector, extra_data=label[i])
      
    i+=1
# Appel de la fonction avec comme paramètre la liste des descripteurs et leurs labels
  return lsh

table_h = table_hash(descripteur, label)

# %%
# Création d'un fichier pickle pour sauver la table de hachage 
# pickle permet de que l'objet puisse garder son type dans le fichier texte
# Ce fichier devra nous aider lors du déploiement sur streamlit
with open("lsh_table.pickle", "wb") as file:
    pickle.dump(table_h, file, pickle.HIGHEST_PROTOCOL)

# %%
# lecture de notre fichier pickle
with open("lsh_table.pickle", "rb") as file:
    table_has = pickle.load(file)

# %%
# Calcul des descripteurs de nos fichier images provenant des frames de nos vidéos pour l'évaluation de nos requètes
descripteur_test = calcul_descripteur_sift(image_test, seuil =200)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Requète teste sur le premier élément de nos fichiers images provent de la frame de nos différentes vidéos
def afficher_resulta_une_frame(descripteur_test, table_has):
  finalDecompt = {}
  # Permet d'observer le temps de traitement restant
  with tqdm(total = len(descripteur_test), desc = 'charement', bar_format="{l_bar}{l_bar} [time left: {remaining}]") as pbar:
    for element in descripteur_test:
      # Indexation en utilisant chaque vecteur de nos descripteurs grace à l'utilisation euclidienne
      nn = table_h.query(element, num_results=1, distance_func="euclidean")
      for ((vec,extra_data),distance) in nn:
        if extra_data not in finalDecompt:
          finalDecompt[extra_data] = 1
        else:
          finalDecompt[extra_data] +=1
      pbar.update(1)
    # finalDecompt = dict(sorted(finalDecompt.items(), key=lambda item: item[1], reverse = True))
  return finalDecompt

h = afficher_resulta_une_frame(descripteur_test[0], table_h)
print('\n')
print('Le résultat pour le cas du fichier '+str(fichier_name_test[0]))
print('\n')
print(h)
# Out:
# charement: 100%|charement: 100%| [time left: 00:00]
# Le résultat pour le cas du fichier 22-BL
#
#
# {'0046': 1, '0001': 7, '0056': 20, '0032': 10, '0029': 3, '0022': 29, '0024': 3, '0033': 3, '0020': 9, '0049': 5, '0031': 9, '0053': 5, '0047': 1, '0034': 1, '0036': 8, '0038': 2, '0039': 7, '0002': 17, '0025': 4, '0008': 7, '0023': 4, '0035': 2, '0037': 4, '0028': 9, '0052': 3, '0016': 1, '0007': 4, '0017': 1, '0015': 4, '0042': 4, '0027': 3, '0006': 1, '0048': 3, '0041': 3, '0026': 2, '0055': 1}

# %%
# Affiche de l'histogramme de la requète pour un document donné plus haut
import seaborn as sns
keys = [cle for cle in h]
vals = [int(h[cle]) for cle in h]
sns.set()
plt.figure(figsize = (9,9))
sns.barplot(x=vals, y=keys)
plt.title("Histogramme d'apparition pour le documents "+str(fichier_name_test[0]), fontsize = 18)
plt.ylabel("Documents", fontsize = 15)
plt.xlabel("Nombre de correspondance", fontsize = 15)
plt.savefig("Fréquence d'apparition des documents")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# # Requète pour les données images de tests afin d'évaluer notre modèle

# %%
def afficher_resulta_tout_frame(descripteur_test, table_has, label_frame):
  finalDecompt = {}
  with tqdm(total = len(descripteur_test), desc = 'charement', bar_format="{l_bar}{l_bar} [time left: {remaining}]") as pbar:
    for i, des in enumerate(descripteur_test):
      dict_frame = {}
      for element in des:
        nn = table_h.query(element, num_results=1, distance_func="cosine")
        for ((vec,extra_data),distance) in nn:
          if extra_data not in dict_frame:
            dict_frame[extra_data] = 1
          else:
            dict_frame[extra_data] +=1
      dic = dict(sorted(dict_frame.items(), key=lambda item: item[1], reverse = True))
      finalDecompt[label_frame[i]] = dic
      pbar.update(1)
  return finalDecompt

model = afficher_resulta_tout_frame(descripteur_test, table_h, fichier_name_test)
# Out:
# charement: 100%|charement: 100%| [time left: 00:00]

# %%
def label_ordonne(mp4_names):
  label = []
  for name in mp4_names:
    a = name.split('/')
    c, d = a[len(a)-1].split('.')
    label.append(c)
  return label

nom_frame = label_ordonne(mp4_names)

# %% [markdown]
# # Fonction permettant d'évaluer notre modèle obtenu par le calcul du rappel

# %%
def evaluation_indexation(model, classe_vrai, nom_frame, k):
  i = 0
  som = 0
  for name in nom_frame:
    # print(name)
    # Prendre les k premiers éléments du dictionnaire model
    l_key = list(model[name].keys())[:k]
    # Si le kième élément est dans la liste 
    # Incrémenter le taux
    if classe_vrai[i] in l_key:
      som += 1
    i += 1
    # print(som)
  return som/len(model) * 100

# %%
# Appel de la fonction de rappel
rappel = evaluation_indexation(model, classe_vrai, nom_frame, k=1)
print("Le rappel de notre model d'indexation est de: "+str(rappel))
# Out:
# Le rappel de notre model d'indexation est de: 47.82608695652174

# %%
# Création de notre fichier json pour sauver notre model
# json = json.dumps(model, indent = len(model))
with open("/content/indexation.json", "w") as outfile:
    json.dump(model, outfile)
